# %%
# !pip install llama-index-llms-ollama llama-index-embeddings-ollama llama-index-readers-file
# !pip install llama-index llama-index-core pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index-llms-ollama in c:\users\7jin\appdata\roaming\python\python312\site-packages (0.8.0)
# Requirement already satisfied: llama-index-embeddings-ollama in c:\users\7jin\appdata\roaming\python\python312\site-packages (0.8.3)
# Requirement already satisfied: llama-index-readers-file in c:\users\7jin\appdata\roaming\python\python312\site-packages (0.5.4)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.3 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-llms-ollama) (0.14.4)
# Requirement already satisfied: ollama>=0.5.1 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-llms-ollama) (0.6.0)
# Requirement already satisfied: pytest-asyncio>=0.23.8 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-embeddings-ollama) (1.2.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in c:\programdata\anaconda3\lib\site-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: defusedxml>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from llama-index-readers-file) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-readers-file) (2.2.2)
# Requirement already satisfied: pypdf<7,>=5.1.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-readers-file) (5.8.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-readers-file) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file) (2.5)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.9.5)
# Requirement already satisfied: aiosqlite in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.2.0)
# Requirement already satisfied: dataclasses-json in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2024.3.1)
# Requirement already satisfied: httpx in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.27.0)
# Requirement already satisfied: llama-index-workflows<3,>=2 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.8.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.9.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (10.3.0)
# Requirement already satisfied: platformdirs in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (4.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.12.0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (6.0.1)
# Requirement already satisfied: requests>=2.31.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.32.2)
# Requirement already satisfied: setuptools>=80.9.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.0.30)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file) (2023.3)
# Requirement already satisfied: pytest<9,>=8.2 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from pytest-asyncio>=0.23.8->llama-index-embeddings-ollama) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.9.3)
# Requirement already satisfied: griffe in c:\users\7jin\appdata\roaming\python\python312\site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.14.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.1.4)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.0.2)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.7)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-workflows<3,>=2->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.4.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (0.4.2)
# Requirement already satisfied: colorama>=0.4 in c:\programdata\anaconda3\lib\site-packages (from pytest<9,>=8.2->pytest-asyncio>=0.23.8->llama-index-embeddings-ollama) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\programdata\anaconda3\lib\site-packages (from pytest<9,>=8.2->pytest-asyncio>=0.23.8->llama-index-embeddings-ollama) (1.1.1)
# Requirement already satisfied: packaging>=20 in c:\programdata\anaconda3\lib\site-packages (from pytest<9,>=8.2->pytest-asyncio>=0.23.8->llama-index-embeddings-ollama) (23.2)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from pytest<9,>=8.2->pytest-asyncio>=0.23.8->llama-index-embeddings-ollama) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\programdata\anaconda3\lib\site-packages (from pytest<9,>=8.2->pytest-asyncio>=0.23.8->llama-index-embeddings-ollama) (2.15.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (3.26.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.3->llama-index-llms-ollama) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index in c:\users\7jin\appdata\roaming\python\python312\site-packages (0.14.4)
# Requirement already satisfied: llama-index-core in c:\users\7jin\appdata\roaming\python\python312\site-packages (0.14.4)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (10.3.0)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (0.9.4)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (0.6.4)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (0.5.4)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index) (3.9.2)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (3.9.5)
# Requirement already satisfied: aiosqlite in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (2.2.0)
# Requirement already satisfied: dataclasses-json in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (2024.3.1)
# Requirement already satisfied: httpx in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: llama-index-workflows<3,>=2 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (2.8.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (3.2.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: platformdirs in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (4.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (2.12.0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: requests>=2.31.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (2.32.2)
# Requirement already satisfied: setuptools>=80.9.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core) (2.0.30)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core) (1.9.3)
# Requirement already satisfied: griffe in c:\users\7jin\appdata\roaming\python\python312\site-packages (from banks<3,>=2.2.0->llama-index-core) (1.14.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from banks<3,>=2.2.0->llama-index-core) (3.1.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.109.1)
# Requirement already satisfied: llama-cloud==0.1.35 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: certifi>=2024.7.4 in c:\programdata\anaconda3\lib\site-packages (from llama-cloud==0.1.35->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.1.31)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.0.2)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core) (3.7)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in c:\programdata\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.12.3)
# Requirement already satisfied: defusedxml>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in c:\programdata\anaconda3\lib\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<7,>=5.1.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (5.8.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-index-workflows<3,>=2->llama-index-core) (0.4.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from pydantic>=2.8.0->llama-index-core) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from pydantic>=2.8.0->llama-index-core) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core) (3.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from dataclasses-json->llama-index-core) (3.26.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.5)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (23.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2023.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core) (2.1.3)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in c:\users\7jin\appdata\roaming\python\python312\site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.16.0)

# %%
import os
import glob
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.ollama import OllamaEmbedding
from llama_index.core.schema import TextNode
from llama_index.core.response_synthesizers import get_response_synthesizer
# Out:
# C:\Users\7JIN\AppData\Roaming\Python\Python312\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
# --- Configuration ---
MOONDREAM_MODEL = "moondream"           # For image processing (VLM)
GEMMA_MODEL = "gemma3"                  # For final text synthesis (LLM)
EMBED_MODEL = "nomic-embed-text"        # For generating vector embeddings
DATA_DIR = "./textbooks"

# %%
# Initialize Clients
moondream_client = Ollama(model=MOONDREAM_MODEL, request_timeout=180.0) 
gemma_client = Ollama(model=GEMMA_MODEL, request_timeout=120.0)

# %%
# Set Global Settings for the RAG Index (used for embedding and final generation)
Settings.llm = gemma_client # Gemma 3 handles the final answer synthesis
Settings.embed_model = OllamaEmbedding(model_name=EMBED_MODEL)
print(f"Synthesis LLM set to: {GEMMA_MODEL}")
print(f"Embedding Model set to: {EMBED_MODEL}")
# Out:
# Synthesis LLM set to: gemma3
# Embedding Model set to: nomic-embed-text

# %%
# Load all documents/files
documents = SimpleDirectoryReader(DATA_DIR).load_data()
print(f"Loaded {len(documents)} initial documents/files.")

multimodal_nodes = []
image_files = glob.glob(os.path.join(DATA_DIR, "*.[jJpP]*"))
print(f"Found {len(image_files)} images to process using {MOONDREAM_MODEL}.")

for image_path in image_files:
    print(f"Processing image: {image_path}...")
    try:
        # Moondream processes the image and returns a text caption
        response = moondream_client.generate(
            prompt="Describe this image in detail, focusing on key content and context for a RAG system.",
            images=[image_path] 
        )
        
        caption = response.text.strip()
        
        # Create a TextNode to represent the image data
        image_node = TextNode(
            text=f"Image Description for {os.path.basename(image_path)}: {caption}",
            metadata={"file_path": image_path, "type": "moondream_description"}
        )
        multimodal_nodes.append(image_node)
        print(f"  -> Caption: {caption[:50]}...")
        
    except Exception as e:
        print(f"Error processing {image_path}: {e}")

# Combine text documents and image description nodes
all_nodes = documents + multimodal_nodes
print(f"Total nodes for indexing: {len(all_nodes)}")
# Out:
# Loaded 4354 initial documents/files.
# Found 51 images to process using moondream.
# Processing image: ./textbooks\2019BurkovTheHundred-pageMachineLearning.pdf...
# Error processing ./textbooks\2019BurkovTheHundred-pageMachineLearning.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\Cloud Computing - Theory and Practice- Marinescu, Dan C.pdf...
# Error processing ./textbooks\Cloud Computing - Theory and Practice- Marinescu, Dan C.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\cryptography.pdf...
# Error processing ./textbooks\cryptography.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\Data Science.pdf...
# Error processing ./textbooks\Data Science.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf...
# Error processing ./textbooks\Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\Internet-of-things-a-hands-on-approach- Arshadeep.pdf...
# Error processing ./textbooks\Internet-of-things-a-hands-on-approach- Arshadeep.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech101.pdf...
# Error processing ./textbooks\lech101.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech102.pdf...
# Error processing ./textbooks\lech102.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech103.pdf...
# Error processing ./textbooks\lech103.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech104.pdf...
# Error processing ./textbooks\lech104.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech105.pdf...
# Error processing ./textbooks\lech105.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech1a1.pdf...
# Error processing ./textbooks\lech1a1.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech1an.pdf...
# Error processing ./textbooks\lech1an.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lech1ps.pdf...
# Error processing ./textbooks\lech1ps.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh101.pdf...
# Error processing ./textbooks\lemh101.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh102.pdf...
# Error processing ./textbooks\lemh102.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh103.pdf...
# Error processing ./textbooks\lemh103.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh104.pdf...
# Error processing ./textbooks\lemh104.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh105.pdf...
# Error processing ./textbooks\lemh105.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh106.pdf...
# Error processing ./textbooks\lemh106.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh1a1.pdf...
# Error processing ./textbooks\lemh1a1.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh1a2.pdf...
# Error processing ./textbooks\lemh1a2.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh1an.pdf...
# Error processing ./textbooks\lemh1an.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh1ps.pdf...
# Error processing ./textbooks\lemh1ps.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh201.pdf...
# Error processing ./textbooks\lemh201.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh202.pdf...
# Error processing ./textbooks\lemh202.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh203.pdf...
# Error processing ./textbooks\lemh203.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh204.pdf...
# Error processing ./textbooks\lemh204.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh205.pdf...
# Error processing ./textbooks\lemh205.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh206.pdf...
# Error processing ./textbooks\lemh206.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh207.pdf...
# Error processing ./textbooks\lemh207.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh2an.pdf...
# Error processing ./textbooks\lemh2an.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\lemh2ps.pdf...
# Error processing ./textbooks\lemh2ps.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph101.pdf...
# Error processing ./textbooks\leph101.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph102.pdf...
# Error processing ./textbooks\leph102.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph103.pdf...
# Error processing ./textbooks\leph103.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph104.pdf...
# Error processing ./textbooks\leph104.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph105.pdf...
# Error processing ./textbooks\leph105.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph106.pdf...
# Error processing ./textbooks\leph106.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph107.pdf...
# Error processing ./textbooks\leph107.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph108.pdf...
# Error processing ./textbooks\leph108.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph1an.pdf...
# Error processing ./textbooks\leph1an.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph1ps.pdf...
# Error processing ./textbooks\leph1ps.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph201.pdf...
# Error processing ./textbooks\leph201.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph202.pdf...
# Error processing ./textbooks\leph202.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph203.pdf...
# Error processing ./textbooks\leph203.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph204.pdf...
# Error processing ./textbooks\leph204.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph205.pdf...
# Error processing ./textbooks\leph205.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph206.pdf...
# Error processing ./textbooks\leph206.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\leph2ps.pdf...
# Error processing ./textbooks\leph2ps.pdf: 'Ollama' object has no attribute 'generate'
# Processing image: ./textbooks\mml-book.pdf...
# Error processing ./textbooks\mml-book.pdf: 'Ollama' object has no attribute 'generate'
# Total nodes for indexing: 4354

# %%
# The embedding model indexes all text data
print("Creating and indexing the vector store...")
index = VectorStoreIndex.from_documents(all_nodes)
print("Indexing complete.")

# Create the query engine. It uses Gemma 3 for the final response.
query_engine = index.as_query_engine(
    similarity_top_k=5, 
    response_mode="compact" # Recommended for RAG tasks
)

# --- Query 1: Pure document retrieval and Gemma synthesis ---
query_text = "Summarize the key findings from the annual report."
print(f"\n--- Query 1: {query_text} ---")
response_text = query_engine.query(query_text)
print("Response (via Gemma 3):\n", str(response_text))

# --- Query 2: Multimodal retrieval (uses Moondream's description) and Gemma synthesis ---
query_image = "Based on the image descriptions, what visual data supports the claim about market share growth?"
print(f"\n--- Query 2: {query_image} ---")
response_image = query_engine.query(query_image)
print("Response (via Gemma 3):\n", str(response_image))
# Out:
# Creating and indexing the vector store...
# 2025-10-11 16:31:44,587 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:44,845 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:46,423 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:47,529 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:47,730 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:48,026 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:49,743 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:51,268 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:53,043 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:54,569 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:55,790 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:57,608 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:57,992 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:58,181 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:58,420 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:31:59,535 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:01,222 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:02,827 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:04,176 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:04,864 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:06,570 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:07,554 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:08,892 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:10,251 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:11,856 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:12,786 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:12,954 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:13,173 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:14,518 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:15,373 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:17,065 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:17,914 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:18,861 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:20,426 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:21,510 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:23,219 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:24,531 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:25,363 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:26,915 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:27,760 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:29,653 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:31,133 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:31,296 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:31,517 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:32,710 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:33,503 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:34,900 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:36,191 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:36,879 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:38,234 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:39,843 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:40,004 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:40,237 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:41,691 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:43,338 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:44,741 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:46,072 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:47,523 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:48,749 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:48,950 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:50,482 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:51,625 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:52,854 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:54,305 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:55,621 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:56,741 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:58,037 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:58,741 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:32:59,514 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:01,092 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:02,497 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:02,664 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:02,879 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:04,285 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:05,363 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:05,796 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:06,687 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:07,637 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:08,701 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:09,525 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:10,359 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:11,510 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:12,261 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:13,619 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:14,791 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:14,983 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:15,466 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:16,329 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:17,418 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:18,553 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:19,377 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:20,266 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:21,201 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:22,310 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:23,477 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:24,753 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:26,346 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:28,065 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:28,970 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:29,886 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:31,274 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:32,286 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:33,925 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:35,348 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:36,878 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:38,349 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:38,522 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:38,774 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:39,698 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:41,038 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:43,044 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:44,648 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:46,219 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:47,799 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:49,233 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:50,698 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:51,752 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:51,926 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:52,176 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:53,420 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:54,105 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:55,554 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:56,130 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:57,947 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:33:59,474 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:00,397 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:01,192 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:02,751 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:03,189 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:04,400 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:05,550 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:06,645 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:07,982 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:08,814 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:09,017 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:09,264 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:10,372 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:11,639 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:13,447 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:14,730 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:16,072 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:17,705 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:19,349 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:20,738 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:22,346 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:22,737 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:22,912 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:23,183 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:24,373 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:25,726 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:26,963 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:27,378 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:27,517 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:27,671 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:27,826 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:28,085 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:29,198 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:29,367 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:29,531 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:33,991 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:38,373 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:42,738 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:47,000 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:49,889 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:50,163 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:51,801 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:53,546 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:55,318 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:57,049 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:58,348 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:58,496 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:34:59,957 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:01,425 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:03,058 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:04,792 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:06,329 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:08,082 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:09,718 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:11,686 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:13,274 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:14,688 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:15,640 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:16,364 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:17,778 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:19,261 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:20,850 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:22,500 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:24,047 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:25,462 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:26,317 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:26,455 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:27,816 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:29,207 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:30,871 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:32,432 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:33,979 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:35,687 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:36,862 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:37,887 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:39,655 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:41,038 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:42,420 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:43,621 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:45,366 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:46,660 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:47,894 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:48,825 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:50,128 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:51,579 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:53,552 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:54,775 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:55,591 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:57,183 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:57,909 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:35:59,514 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:01,107 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:02,173 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:02,983 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:04,797 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:07,050 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:08,757 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:10,466 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:11,885 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:13,434 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:17,616 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:20,650 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:23,304 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:26,153 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:28,103 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:28,473 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:29,484 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:30,610 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:32,184 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:34,184 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:35,593 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:36,365 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:36,494 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:37,878 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:39,706 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:40,365 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:42,027 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:43,924 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:45,050 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:46,472 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:47,159 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:48,904 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:49,979 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:51,629 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:53,206 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:54,218 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:55,658 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:56,470 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:57,928 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:36:59,261 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:00,767 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:01,260 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:02,731 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:04,296 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:06,057 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:07,043 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:08,704 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:10,067 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:11,636 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:12,422 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:13,704 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:14,454 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:15,564 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:16,711 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:17,311 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:18,464 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:19,730 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:20,979 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:22,172 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:23,656 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:25,150 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:26,468 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:27,187 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:28,791 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:29,836 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:30,483 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:32,011 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:33,341 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:34,830 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:35,703 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:36,828 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:38,061 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:39,501 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:40,377 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:41,881 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:42,362 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:43,600 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:44,904 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:46,610 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:48,175 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:49,825 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:51,401 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:52,527 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:53,501 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:55,130 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:56,978 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:58,307 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:37:59,788 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:01,266 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:02,646 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:03,670 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:04,425 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:05,979 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:06,804 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:08,206 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:09,768 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:11,055 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:12,028 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:13,679 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:14,904 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:16,479 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:17,599 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:18,811 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:20,458 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:20,855 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:22,799 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:23,986 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:25,548 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:27,206 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:28,673 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:30,242 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:31,220 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:32,890 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:33,911 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:35,385 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:36,500 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:37,966 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:38,838 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:38,991 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:40,461 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:41,784 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:43,032 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:44,433 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:45,789 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:47,284 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:48,706 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:49,657 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:51,069 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:52,391 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:53,317 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:54,739 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:55,865 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:56,737 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:57,679 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:38:59,212 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:00,933 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:02,044 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:03,102 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:04,573 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:05,406 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:07,076 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:08,092 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:09,039 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:10,090 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:10,829 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:11,956 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:13,145 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:14,773 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:15,727 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:17,101 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:17,891 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:19,926 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:21,735 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:22,491 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:23,740 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:24,539 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:25,645 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:27,072 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:28,583 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:29,818 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:29,934 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:31,094 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:32,267 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:33,734 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:34,803 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:35,681 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:37,241 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:38,543 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:39,268 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:39,875 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:40,461 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:41,877 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:43,037 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:44,094 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:45,424 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:46,215 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:47,867 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:49,888 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:50,863 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:51,862 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:52,325 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:53,750 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:55,319 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:56,672 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:57,919 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:39:59,399 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:00,866 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:01,931 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:03,008 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:04,177 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:05,547 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:06,820 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:07,901 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:08,920 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:10,003 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:11,189 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:11,782 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:13,019 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:14,315 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:15,348 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:16,550 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:18,022 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:18,990 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:20,262 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:21,109 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:21,991 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:23,013 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:24,527 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:26,005 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:26,521 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:28,137 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:29,376 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:30,663 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:31,589 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:32,848 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:33,621 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:34,962 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:35,729 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:37,277 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:38,166 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:39,520 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:41,023 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:42,487 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:43,421 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:44,840 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:45,412 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:46,842 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:47,816 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:47,927 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:49,222 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:50,677 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:52,204 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:52,938 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:54,254 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:55,590 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:56,919 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:58,234 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:40:59,582 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:01,046 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:02,313 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:03,651 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:04,960 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:06,492 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:08,015 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:09,703 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:11,439 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:13,299 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:15,016 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:16,525 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:17,565 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-10-11 16:41:19,425 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# ...
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[14], line 15
#      13 query_text = "Summarize the key findings from the annual report."
#      14 print(f"\n--- Query 1: {query_text} ---")
# ---> 15 response_text = query_engine.query(query_text)
#      16 print("Response (via Gemma 3):\n", str(response_text))
#      18 # --- Query 2: Multimodal retrieval (uses Moondream's description) and Gemma synthesis ---
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\base\base_query_engine.py:44, in BaseQueryEngine.query(self, str_or_query_bundle)
#      42     if isinstance(str_or_query_bundle, str):
#      43         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 44     query_result = self._query(str_or_query_bundle)
#      45 dispatcher.event(
#      46     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      47 )
#      48 return query_result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\query_engine\retriever_query_engine.py:197, in RetrieverQueryEngine._query(self, query_bundle)
#     193 with self.callback_manager.event(
#     194     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     195 ) as query_event:
#     196     nodes = self.retrieve(query_bundle)
# --> 197     response = self._response_synthesizer.synthesize(
#     198         query=query_bundle,
#     199         nodes=nodes,
#     200     )
#     201     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     203 return response
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\response_synthesizers\base.py:235, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     229     query = QueryBundle(query_str=query)
#     231 with self._callback_manager.event(
#     232     CBEventType.SYNTHESIZE,
#     233     payload={EventPayload.QUERY_STR: query.query_str},
#     234 ) as event:
# --> 235     response_str = self.get_response(
#     236         query_str=query.query_str,
#     237         text_chunks=[
#     238             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     239         ],
#     240         **response_kwargs,
#     241     )
#     243     additional_source_nodes = additional_source_nodes or []
#     244     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\response_synthesizers\refine.py:179, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     175 for text_chunk in text_chunks:
#     176     if prev_response is None:
#     177         # if this is the first chunk, and text chunk already
#     178         # is an answer, then return it
# --> 179         response = self._give_response_single(
#     180             query_str, text_chunk, **response_kwargs
#     181         )
#     182     else:
#     183         # refine response if possible
#     184         response = self._refine_response_single(
#     185             prev_response, query_str, text_chunk, **response_kwargs
#     186         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\response_synthesizers\refine.py:241, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     237 if response is None and not self._streaming:
#     238     try:
#     239         structured_response = cast(
#     240             StructuredRefineResponse,
# --> 241             program(
#     242                 context_str=cur_text_chunk,
#     243                 **response_kwargs,
#     244             ),
#     245         )
#     246         query_satisfied = structured_response.query_satisfied
#     247         if query_satisfied:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\response_synthesizers\refine.py:85, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      83         answer = answer.model_dump_json()
#      84 else:
# ---> 85     answer = self._llm.predict(
#      86         self._prompt,
#      87         **kwds,
#      88     )
#      89 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\llms\llm.py:623, in LLM.predict(self, prompt, **prompt_args)
#     621 if self.metadata.is_chat_model:
#     622     messages = self._get_messages(prompt, **prompt_args)
# --> 623     chat_response = self.chat(messages)
#     624     output = chat_response.message.content or ""
#     625 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\llms\callbacks.py:175, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     166 event_id = callback_manager.on_event_start(
#     167     CBEventType.LLM,
#     168     payload={
#    (...)
#     172     },
#     173 )
#     174 try:
# --> 175     f_return_val = f(_self, messages, **kwargs)
#     176 except BaseException as e:
#     177     callback_manager.on_event_end(
#     178         CBEventType.LLM,
#     179         payload={EventPayload.EXCEPTION: e},
#     180         event_id=event_id,
#     181     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\llms\ollama\base.py:347, in Ollama.chat(self, messages, **kwargs)
#     344 think = kwargs.pop("think", None) or self.thinking
#     345 format = kwargs.pop("format", "json" if self.json_mode else None)
# --> 347 response = self.client.chat(
#     348     model=self.model,
#     349     messages=ollama_messages,
#     350     stream=False,
#     351     format=format,
#     352     tools=tools,
#     353     think=think,
#     354     options=self._model_kwargs,
#     355     keep_alive=self.keep_alive,
#     356 )
#     358 response = dict(response)
#     360 blocks: List[TextBlock | ThinkingBlock] = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ollama\_client.py:351, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     306 def chat(
#     307   self,
#     308   model: str = '',
#    (...)
#     316   keep_alive: Optional[Union[float, str]] = None,
#     317 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     318   """
#     319   Create a chat response using the requested model.
#     320
#    (...)
#     349   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     350   """
# --> 351   return self._request(
#     352     ChatResponse,
#     353     'POST',
#     354     '/api/chat',
#     355     json=ChatRequest(
#     356       model=model,
#     357       messages=list(_copy_messages(messages)),
#     358       tools=list(_copy_tools(tools)),
#     359       stream=stream,
#     360       think=think,
#     361       format=format,
#     362       options=options,
#     363       keep_alive=keep_alive,
#     364     ).model_dump(exclude_none=True),
#     365     stream=stream,
#     366   )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ollama\_client.py:129, in Client._request_raw(self, *args, **kwargs)
#     127 def _request_raw(self, *args, **kwargs):
#     128   try:
# --> 129     r = self._client.request(*args, **kwargs)
#     130     r.raise_for_status()
#     131     return r
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_transports\default.py:232, in HTTPTransport.handle_request(self, request)
#     218 assert isinstance(request.stream, SyncByteStream)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File C:\ProgramData\anaconda3\Lib\site-packages\httpx\_transports\default.py:86, in map_httpcore_exceptions()
#      83     raise
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ReadTimeout: timed out
